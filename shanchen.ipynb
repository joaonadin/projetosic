# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import os
import imageio.v2 as imageio 

# Parâmetros
nx = 100
ny = nx
dx, dy = 1 / nx, 1 / ny
u_max = 0.1 / nx
dt = dx / u_max
re = 5
alpha = dx / dt * nx / re
omega = 1 / (3 * alpha + 0.5)
rho0 = 1
t = int(1300)
G = -5
rho_cr = np.log(2)
rho_liq = 1.95
rho_gas = 0.15
count=0

output_dir = os.path.join(os.path.expanduser("~"), "Documents", "PraticaLBM","Densidades")
os.makedirs(output_dir, exist_ok=True)

# Componentes de velocidade e pesos
cx = np.array([0, 1, 0, -1, 0, 1, -1, -1, 1])
cy = np.array([0, 0, 1, 0, -1, 1, 1, -1, -1])
w = np.array([0.4444444444, 0.1111111111, 0.1111111111, 0.1111111111, 
              0.1111111111, 0.0277777777, 0.0277777777, 0.0277777777, 0.0277777777])

# Definição da malha
X, Y = np.meshgrid(np.linspace(dx / 2, dx / 2 + (nx - 1) * dx, nx, dtype='float64'),
                   np.linspace(dy / 2, dy / 2 + (ny - 1) * dy, ny, dtype='float64'), indexing='ij')

# Inicialização das variáveis
f = np.zeros((9, nx, ny), dtype='float64')
fp = np.zeros((9, nx, ny), dtype='float64')
rho = rho_cr + 0.1 * np.random.rand(nx, ny)
print(f"Min rho: {rho.min()}, Max rho: {rho.max()}")
u = np.zeros((nx, ny), dtype='float64')
v = np.zeros((nx, ny), dtype='float64')
uf = np.zeros((nx, ny), dtype='float64')
vf = np.zeros((nx, ny), dtype='float64')
forcx = np.zeros((nx, ny))
forcy = np.zeros((nx, ny))

# Função de força
def force():
    global forcx, forcy
    forcx = np.zeros((nx, ny))
    forcy = np.zeros((nx, ny))
    for j in range(ny):
        for i in range(nx):
            forcxs = 0.0
            forcys = 0.0
            for k in range(8):
                k=k+1
                newx = (i + cx[k] + nx) % nx
                newy = (j + cy[k] + ny) % ny
                psi = 1 - np.exp(-rho[newx, newy])
                forcxs -= G * w[k] * psi * cx[k]
                forcys -= G * w[k] * psi * cy[k]
            forcx[i, j] = (1 - np.exp(-rho[i, j])) * forcxs
            forcy[i, j] = (1 - np.exp(-rho[i, j])) * forcys

# Funções de colisão e transmissão
def fcolisao():
    global fp
    # Precompute terms
    t1 = uf**2 + vf**2  # Squared velocities
    t2 = np.einsum('i,jk->ijk', cx, uf) + np.einsum('i,jk->ijk', cy, vf)  # Dot product of velocity and discrete velocities
    
    # Compute equilibrium distribution function (feq)
    feq = np.zeros_like(f)
    for i in range(9):
        feq[i] = w[i] * rho * (1 + 3 * t2[i] + 4.5 * t2[i]**2 - 1.5 * t1)

    # Compute forcing terms
    ffx = (3 * (cx[:, None, None] - uf) + 9 * cx[:, None, None] * t2) * forcx
    ffy = (3 * (cy[:, None, None] - vf) + 9 * cy[:, None, None] * t2) * forcy
    fftot = w[:, None, None] * (1 - 0.5 * omega) * (ffx + ffy)
    
    # Update population
    fp = f * (1 - omega) + omega * feq + fftot


def ftransmissao():
    global f
    for i in range(9):
        f[i] = np.roll(np.roll(fp[i], int(cx[i]), axis=0), int(cy[i]), axis=1)

def boundary():
    global f
    
    f[3, :, ny - 1] = f[3, :, 0]
    f[7, :, ny - 1] = f[7, :, 0]
    f[6, :, ny - 1] = f[6, :, 0]
    
    f[0, 0, :] = f[0, nx - 1, :]
    f[4, 0, :] = f[4, nx - 1, :]
    f[7, 0, :] = f[7, nx - 1, :]

    f[2, nx - 1, :] = f[2, 0, :]
    f[6, nx - 1, :] = f[6, 0, :]
    f[5, nx - 1, :] = f[5, 0, :]

    f[1, :, 0] = f[1, :, ny - 1]
    f[4, :, 0] = f[4, :, ny - 1]
    f[5, :, 0] = f[5, :, ny - 1]

t1 = uf**2 + vf**2  

for count in range(t):
    force()
    fcolisao()
    ftransmissao()
    boundary()
    
    # Calcula densidade e velocidades
    rho = np.einsum('ijk->jk', f)
    u = (f[1] + f[5] + f[8] - (f[3] + f[6] + f[7])) / rho
    v = (f[2] + f[5] + f[6] - (f[4] + f[7] + f[8])) / rho
    uf = u + 0.5 * forcx / rho
    vf = v + 0.5 * forcy / rho
    
    # Salva imagem a cada 10 passos de tempo
    if count % 10 == 0:  # Salva no 0, 10, 20, ...
        plt.figure(figsize=(6, 6))
        plt.imshow(rho, cmap="viridis", origin="lower")
        plt.colorbar(label="Densidade")
        plt.title(f"Frame {count}")
        plt.savefig(f"{output_dir}frame_{int(count / 10):03d}.png")
        plt.close()

# Criar animação com imagens salvas
import glob

with imageio.get_writer("densidade_animacao.gif", mode="I", duration=0.1) as writer:
    frame_files = sorted(glob.glob(f"{output_dir}frame_*.png"))  # Ordena os frames corretamente
    for filename in frame_files:
        image = imageio.imread(filename)
        writer.append_data(image)

print("Animação salva como 'densidade_animacao.gif'")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 from matplotlib.animation import FuncAnimation
#       4 import os
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
### CODIGO ORIGINAL EM FUNCIONAMENTO  - NAO MEXER !!!!!!!!!!!

import numpy as np
import os
import time
import matplotlib.pyplot as plt


# Parâmetros do lattice
nx = 64  # número de nós ao longo do eixo x
ny = 64  # número de nós ao longo do eixo y
nsteps = 20000  # número de passos de tempo
noutput = 100  # intervalo de saída de dados (dados escritos em "/data")
nfluids = 1  # número de componentes do fluido (escolha 1 ou 2)
tauA = 1  # tempo de relaxação para o fluido A
tauB = 1  # tempo de relaxação para o fluido B (usado apenas se nfluids = 2)

# Parâmetros de Shan-Chen
gA = -4.7  # força de auto-interação do fluido A
gB = 0.  # força de auto-interação do fluido B (usado apenas se nfluids = 2)
gAB = 6.  # força de interação dos fluidos A e B (usado apenas se nfluids = 2)
rho0 = 1.  # densidade de referência para o potencial pseudo (geralmente definido como 1)
rhol = 2.1  # densidade inicial do líquido
rhog = 0.15  # densidade inicial do gás
radius = 15.  # raio inicial da gota

# Parâmetros fixos; NÃO ALTERAR
npop = 9  # número de populações
cx =[0, 1, 0, -1, 0, 1, -1, -1, 1] # componentes x dos vetores do lattice
cy =[0, 0, 1,  0, -1, 1,  1, -1, -1]  # componentes y dos vetores do lattice
weight = [4./9., 1./9., 1./9., 1./9., 1./9., 1./36., 1./36., 1./36., 1./36.]


# Matrizes
g = np.zeros((nfluids, nfluids))  # forças de interação
rho = np.zeros((nfluids, nx, ny))  # densidade
press = np.zeros((nx, ny))  # pressão
ux = np.zeros((nx, ny))  # componente x da velocidade do fluido
uy = np.zeros((nx, ny))  # componente y da velocidade do fluido
psi_s = np.zeros((nx, ny))  # paralelizando calculos
psi_ss = np.zeros((nx, ny))  # paralelizando calculos
psinb = np.zeros((nx, ny))  # paralelizando calculos
# fxtemp=np.zeros((nx, ny))  # paralelizando calculos
# fytemp=np.zeros((nx, ny))  # paralelizando calculos
Fx = np.zeros((nfluids, nx, ny))  # componente x da força de Shan-Chen
Fy = np.zeros((nfluids, nx, ny))  # componente y da força de Shan-Chen
feq = np.zeros((nfluids, npop))  # populações de equilíbrio
forcing = np.zeros((nfluids, npop))  # populações de força
tau = np.zeros(nfluids)  # tempos de relaxação
f1 = np.zeros((nfluids, nx, ny, npop))  # populações (antigo)
f2 = np.zeros((nfluids, nx, ny, npop))  # populações (novo)

output_dir = os.path.join(os.path.expanduser("~"), "Documents", "PraticaLBM","Densidades")
os.makedirs(output_dir, exist_ok=True)



# Função para computar a densidade em todos os pontos

def compute_density(pop):
    global rho
    rho = np.zeros((nfluids, nx, ny))  # A matriz de densidade já é inicializada fora da função
    for s in range(nfluids):
        rho[s] = np.sum(pop, axis=3).reshape(nx, ny)  # Soma todas as direções em cada nó


def computePressure():
    # Inicializa a matriz de pressão com zeros
    press.fill(0.0)
    
    # Calcula o termo de correção de forma vetorizada
    for s in range(nfluids):
        press += rho[s] / 3.0
        for ss in range(nfluids):
            press += (g[s, ss] * 
                      psi(rho[s]) * 
                      psi(rho[ss]) / 6.0)

def psi(densities):
    return rho0 * (1 - np.exp(-densities / rho0))
                    

def computeSCForces():
    # Inicializa as forças SC
    Fx.fill(0.0)
    Fy.fill(0.0)
    xvet=np.arange(nx)
    x2=np.zeros((nx,npop))
    yvet=np.arange(ny)
    y2=np.zeros((ny,npop))
    for x in range(nx):
        for i in range(npop):
            x2[x,i]=xvet[(x + cx[i]) % nx]
            y2[x,i]=yvet[(x + cy[i]) % ny]  ##como y=x nesse caso, usamos o mesmo loop
    # Computa as forças de Shan-Chen (SC)
    for x in range(nx):
        for y in range(ny):
            for s in range(nfluids):
                for ss in range(nfluids):
                    fxtemp=0
                    fytemp=0
                    for i in range(1, npop):  # Ignorar i=0 (sem força)
                        ##fx e fy temp tavam aqui
                        x2var=int(x2[x,i])
                        y2var=int(y2[y,i])
                        psinb[x,y] = rho0 * (1 - np.exp(-rho[s,x2var,y2var] / rho0))  # Psi do vizinho
                        fxtemp += weight[i] * cx[i] * psinb[x,y]
                        fytemp += weight[i] * cy[i] * psinb[x,y]
                        
                    psiloc = rho0 * (1 - np.exp(-rho[s,x,y] / rho0)) # Psi local
                    Fx[s, x, y] -= g[s, ss] * psiloc * fxtemp
                    Fy[s, x, y] -= g[s, ss] * psiloc * fytemp

    
def computeTotalDensity(x, y):
    # Soma a densidade de todos os fluidos no ponto (x, y)
    return np.sum(rho[:, x, y])




# def computePressure():
#     # Inicializa a pressão
#     press.fill(0.0)
#     psi_s.fill(0.0)
#     psi_ss.fill(0.0)
#     press.fill(0.0)
#     press[:, :] += np.sum(rho[:, :, :]) / 3.0
#     # Soma contribuições para a pressão
#     for s in range(nfluids):
#         for ss in range(nfluids):
#             psi_s[:,:] = rho0 * (1 - np.exp(-rho[s, :, :] / rho0))
#             psi_ss[:,:] = rho0 * (1 - np.exp(-rho[ss, :, :] / rho0))
#             press[:, :] += (g[s, ss] * psi_s[:,:] * psi_ss[:,:]) / 6.0

def computePressure():
    # Inicializa a pressão
    press.fill(0.0)
    psi_s = rho0 * (1 - np.exp(-rho / rho0))  # Calcula psi para todos os fluidos de uma vez
    psi_ss = psi_s  # psi_ss é o mesmo que psi_s, já que a operação é simétrica
    press[:, :] += np.sum(rho, axis=0) / 3.0  # Soma as densidades divididas por 3.0

    # Soma contribuições para a pressão com operações vetorizadas
    press[:, :] += np.sum(g[:, :, None, None] * psi_s[:, None, :, :] * psi_ss[None, :, :, :], axis=(0, 1)) / 6.0
                    

# def computeVelocity(pop):
#     for x in range(nx):
#         for y in range(ny):
#             ux[x, y] = 0.0
#             uy[x, y] = 0.0
#             for s in range(nfluids):
#                 # Calcula contribuições da população
#                 ux[x, y] += (pop[s, x, y, 1] - pop[s, x, y, 3] +
#                              pop[s, x, y, 5] - pop[s, x, y, 6] -
#                              pop[s, x, y, 7] + pop[s, x, y, 8])
                
#                 uy[x, y] += (pop[s, x, y, 2] - pop[s, x, y, 4] +
#                              pop[s, x, y, 5] + pop[s, x, y, 6] -
#                              pop[s, x, y, 7] - pop[s, x, y, 8])
                
#                 # Adiciona força
#                 ux[x, y] += 0.5 * Fx[s, x, y]
#                 uy[x, y] += 0.5 * Fy[s, x, y]
            
#             # Normaliza pela densidade total
#             dens = computeTotalDensity(x, y)
#             ux[x, y] /= dens
#             uy[x, y] /= dens

def computeVelocity(pop):
    ux.fill(0.0)
    uy.fill(0.0)
    for s in range(nfluids):
        # Calcula contribuições da população
        ux[:,:] += (pop[s, :, :, 1] - pop[s, :, :, 3] +
                     pop[s, :, :, 5] - pop[s, :, :, 6] -
                     pop[s, :, :, 7] + pop[s, :, :, 8])

        uy[:, :] += (pop[s, :, :, 2] - pop[s, :, :, 4] +
                     pop[s, :, :, 5] + pop[s, :, :, 6] -
                     pop[s, :, :, 7] - pop[s, :, :, 8])

        # Adiciona força
        ux[:, :] += 0.5 * Fx[s, :, :]
        uy[:, :] += 0.5 * Fy[s, :, :]

# Normaliza pela densidade total
    for x in range(nx):
        for y in range(ny):
            dens = computeTotalDensity(x,y)
            ux[x, y] /= dens
            uy[x, y] /= dens

            

def equilibrium(s,x,y):
    dens = rho[s,x,y]
    vx = ux[x,y]
    vy = uy[x,y]
    usq = vx * vx + vy * vy
  
    feq[s][0] = weight[0] * dens * (1. - 1.5 * usq)
    feq[s][1] = weight[1] * dens * (1. + 3. * vx + 4.5 * vx * vx - 1.5 * usq)
    feq[s][2] = weight[2] * dens * (1. + 3. * vy + 4.5 * vy * vy - 1.5 * usq)
    feq[s][3] = weight[3] * dens * (1. - 3. * vx + 4.5 * vx * vx - 1.5 * usq)
    feq[s][4] = weight[4] * dens * (1. - 3. * vy + 4.5 * vy * vy - 1.5 * usq)
    feq[s][5] = weight[5] * dens * (1. + 3. * ( vx + vy) + 4.5 * ( vx + vy) * ( vx + vy) - 1.5 * usq)
    feq[s][6] = weight[6] * dens * (1. + 3. * (-vx + vy) + 4.5 * (-vx + vy) * (-vx + vy) - 1.5 * usq)
    feq[s][7] = weight[7] * dens * (1. + 3. * (-vx - vy) + 4.5 * ( vx + vy) * ( vx + vy) - 1.5 * usq)
    feq[s][8] = weight[8] * dens * (1. + 3. * ( vx - vy) + 4.5 * ( vx - vy) * ( vx - vy) - 1.5 * usq)
  

  
def initialisation(f1, f2):
    # Definir viscosidade
    tau[0] = tauA
    if nfluids == 2:
        tau[1] = tauB

    # Definir força de interação
    g[0, 0] = gA
    if nfluids == 2:
        g[1, 1] = gB
        g[0, 1] = gAB
        g[1, 0] = gAB

    # Inicialização para 1 fluido
    if nfluids == 1:
        x_grid, y_grid = np.meshgrid(np.arange(nx), np.arange(ny), indexing="ij")
        distances = (y_grid - ny / 2.0) ** 2 + (x_grid - nx / 2.0) ** 2
        rho[0] = np.where(distances <= radius ** 2, rhol, rhog)

    # Inicialização para 2 fluidos
    elif nfluids == 2:
        mid_y = ny // 2
        rho[0, :, :mid_y] = 0.1
        rho[1, :, :mid_y] = 0.9
        rho[0, :, mid_y:] = 0.9
        rho[1, :, mid_y:] = 0.1

    # Configurar o campo de velocidade inicial (velocidade zero em todos os lugares)
    ux.fill(0.0)
    uy.fill(0.0)

    # Calcular as distribuições de equilíbrio e inicializar as populações
    for s in range(nfluids):
        for y in range(ny):
            for x in range(nx):
                equilibrium(s, x, y)
                f1[s, x, y, :] = feq[s, :]
                f2[s, x, y, :] = feq[s, :]    
    
def push(f1, f2):
    for s in range(nfluids):
        omega = 1.0 / tau[s]

        for x in range(nx):  
            for y in range(ny):  
                for i in range(npop):
                    forcing[s,i] = weight[i] * (1.0 - 0.5 * omega) * \
                        ((3.0 * (cx[i] - ux[x, y]) + 9.0 * cx[i] * (cx[i] * ux[x, y] + cy[i] * uy[x, y])) * Fx[s, x, y] +
                         (3.0 * (cy[i] - uy[x, y]) + 9.0 * cy[i] * (cx[i] * ux[x, y] + cy[i] * uy[x, y])) * Fy[s, x, y])

                # Compute equilibrium distributions
                equilibrium(s, x, y)

                # Collide and propagate
                for i in range(npop):
                    x2 = (x + cx[i] + nx) % nx  # Periodic boundary in x
                    y2 = (y + cy[i] + ny) % ny  # Periodic boundary in y
                    f2[s, x2, y2, i] = f1[s, x, y, i] * (1.0 - omega) + feq[s, i] * omega + forcing[s,i]

    return

                 
def write_file(name, data, n):
    #Função auxiliar para salvar dados em disco.
    name = os.path.expanduser(os.path.join("~", "Documents", "PraticaLBM","Densidades"))
    # Verifique se o diretório existe, caso contrário, crie-o
    os.makedirs(os.path.dirname(name), exist_ok=True)
    with open(name, "w") as fout:
        for y in range(ny):
            for x in range(nx):
                fout.write(f"{data[y * nx + x]} ")
            fout.write("\n")
        fout.write("\n")


def write_profiles(step):
    """
    Função para salvar os perfis (densidade, pressão, velocidades) no disco.
    """
    # Converter o número do passo em string com zero-padding
    step_str = str(step).zfill(5)

    # Salvar os perfis de pressão e velocidades
    press_filename = f"press_{step_str}.dat"
    velx_filename = f"velx_{step_str}.dat"
    vely_filename = f"vely_{step_str}.dat"

    write_file(press_filename, press, nx * ny)
    write_file(velx_filename, ux, nx * ny)
    write_file(vely_filename, uy, nx * ny)

    # Salvar os perfis de densidade para cada componente de fluido
    for s in range(nfluids):
        density_filename = f"density_comp{s}_{step_str}.dat"
        write_file(density_filename, rho[s], nx * ny)


def calculate_delta_pressure():
    """
    Calcula a pressão de Laplace e imprime densidades, diferenças de pressão, 
    raio da gota e tensão superficial.
    """
    rho_gas = 0.0
    rho_liq = 0.0
    press_gas = 0.0
    press_liq = 0.0

    # Pressão média do gás em um quadrado de 4 nós de malha
    for x in range(4):
        for y in range(4):
            rho_gas += rho[0,x,y]
            press_gas += press[x,y]

    # Pressão média do líquido em um quadrado de 4 nós de malha no centro
    for x in range(nx // 2 - 2, nx // 2 + 2):
        for y in range(ny // 2 - 2, ny // 2 + 2):
            rho_liq += rho[0,x,y]
            press_liq += press[x,y]

    # Calcula médias
    rho_gas /= 16.0
    rho_liq /= 16.0
    press_gas /= 16.0
    press_liq /= 16.0

    # Diferença de pressão e densidade média
    delta_press = press_liq - press_gas
    rho_av = 0.5 * (rho_gas + rho_liq)
    y = ny // 2
    rad = None

    # Determina o raio da gota
    for x in range(nx // 2):
        if rho[0,x,y] > rho_av:
            drho = rho[0,x,y] - rho[0,x-1,y]
            dx = (rho_av - rho[0,x-1,y]) / drho
            rad = (nx / 2.0 - x) + (1.0 - dx)
            break

    # Calcula a tensão superficial
    gamma = delta_press * rad

    # Imprime os resultados
    print(f"  Densities: rho_g = {rho_gas}, rho_l = {rho_liq}")
    print(f"  Pressure difference: dp = {delta_press}")
    print(f"  Droplet radius: r = {rad}")
    print(f"  Surface tension: gamma = {gamma}")

    return


# Função para imprimir status, fora do Numba
def print_status(step, elapsed_time):
    print("Running time step {}".format(step))
    print("Overall CPU time required: {:.2f} sec".format(elapsed_time))
    mlups = nx * ny * nsteps / (elapsed_time * 1e6)
    print("This corresponds to {:.2f} MLUPS".format(mlups))

# Função para criar animação, fora do Numba
def create_animation(output_dir):
    with imageio.get_writer("densidade_animacao.gif", mode="I", duration=0.1) as writer:
        frame_files = sorted(glob.glob("{}frame_*.png".format(output_dir)))  # Ordena os frames corretamente
        for filename in frame_files:
            image = imageio.imread(filename)
            writer.append_data(image)

    print("Animação salva como 'densidade_animacao.gif'")

def main():
    # Configurar cronômetro da simulação
    start = time.time()

    # Alocar memória para populações
    f1 = np.zeros((nfluids, nx, ny, npop))  # Populações antigas
    f2 = np.zeros((nfluids, nx, ny, npop))  # Populações novas
    # Inicializar domínio
    initialisation(f1, f2)

    # Loop principal
    for step in range(nsteps + 1):
        # Calcular campo de densidade
        compute_density(f1)

        # Calcular forças SC
        computeSCForces()

        # Calcular velocidade baricêntrica
        computeVelocity(f1)

        # Colidir e propagar
        push(f1, f2)

        # Trocar populações antigas e novas
        f1, f2 = f2, f1

        # Escrever dados em disco/console
        if step % noutput == 0:
            print_status(step, time.time() - start)
            computePressure()
            #write_profiles(step)
            calculate_delta_pressure()
            rho_summed = np.einsum('sxy->xy', rho)
            rho_matriz = rho_summed.reshape(nx, ny)
            plt.figure(figsize=(6, 6))
            plt.imshow(rho_matriz, cmap="viridis", origin="lower")
            plt.colorbar(label="Densidade")
            plt.title("Frame {}".format(step))
            plt.savefig("{}frame_{:03d}.png".format(output_dir, int(step / 10)))
            plt.close()

    # Exibir estatísticas de desempenho
    finish = time.time()
    elapsed_time = finish - start
    print_status(nsteps, elapsed_time)  # Imprimir estatísticas no final

# Chamar a função principal
if __name__ == "__main__":
    main()

#Criar animação após a execução do cálculo
create_animation(output_dir)

### CODIGO ORIGINAL EM FUNCIONAMENTO  - NAO MEXER !!!!!!!!!!!
# Out:
# Running time step 0
# Overall CPU time required: 0.26 sec
# This corresponds to 313.30 MLUPS
#   Densities: rho_g = 0.14999999999999997, rho_l = 2.1000000000000005
#   Pressure difference: dp = 0.06196697888838586
#   Droplet radius: r = 15.5
#   Surface tension: gamma = 0.9604881727699808
# Running time step 100
# Overall CPU time required: 22.11 sec
# This corresponds to 3.71 MLUPS
#   Densities: rho_g = 0.24713655112712946, rho_l = 0.2478824713550728
#   Pressure difference: dp = 3.626802089425063e-05
#   Droplet radius: r = 20.79283522111776
#   Surface tension: gamma = 0.0007541149822502093
# Running time step 200
# Overall CPU time required: 43.91 sec
# This corresponds to 1.87 MLUPS
#   Densities: rho_g = 0.16512749875777133, rho_l = 0.3445171771682526
#   Pressure difference: dp = 0.008617418393895147
#   Droplet radius: r = 19.274791687648612
#   Surface tension: gamma = 0.16609894442764045
# Running time step 300
# Overall CPU time required: 66.04 sec
# This corresponds to 1.24 MLUPS
#   Densities: rho_g = 0.17966939977902724, rho_l = 1.5790755934775718
#   Pressure difference: dp = -0.005981553904639045
#   Droplet radius: r = 16.868359637292258
#   Surface tension: gamma = -0.10089900245330116
# Running time step 400
# Overall CPU time required: 88.14 sec
# This corresponds to 0.93 MLUPS
#   Densities: rho_g = 0.20133549006743526, rho_l = 1.8151329223240111
#   Pressure difference: dp = 0.014963035992670543
#   Droplet radius: r = 15.68546190440898
#   Surface tension: gamma = 0.2347021310373342
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 432
#     430 # Chamar a função principal
#     431 if __name__ == "__main__":
# --> 432     main()
#     434 #Criar animação após a execução do cálculo
#     435 create_animation(output_dir)
#
# Cell In[4], line 405, in main()
#     402 computeVelocity(f1)
#     404 # Colidir e propagar
# --> 405 push(f1, f2)
#     407 # Trocar populações antigas e novas
#     408 f1, f2 = f2, f1
#
# Cell In[4], line 261, in push(f1, f2)
#     259 for y in range(ny):
#     260     for i in range(npop):
# --> 261         forcing[s,i] = weight[i] * (1.0 - 0.5 * omega) * \
#     262             ((3.0 * (cx[i] - ux[x, y]) + 9.0 * cx[i] * (cx[i] * ux[x, y] + cy[i] * uy[x, y])) * Fx[s, x, y] +
#     263              (3.0 * (cy[i] - uy[x, y]) + 9.0 * cy[i] * (cx[i] * ux[x, y] + cy[i] * uy[x, y])) * Fy[s, x, y])
#     265     # Compute equilibrium distributions
#     266     equilibrium(s, x, y)
#
# KeyboardInterrupt:

# %%
### CODIGO MODIFICADO PARA INICIALIZAÇÃO ALEATÓRIA

import numpy as np
import os
import time
import matplotlib.pyplot as plt


# Parâmetros do lattice
nx = 64  # número de nós ao longo do eixo x
ny = 64  # número de nós ao longo do eixo y
nsteps = 2000  # número de passos de tempo
noutput = 5  # intervalo de saída de dados (dados escritos em "/data")
nfluids = 1  # número de componentes do fluido (escolha 1 ou 2)
tauA = 1  # tempo de relaxação para o fluido A
tauB = 1  # tempo de relaxação para o fluido B (usado apenas se nfluids = 2)

# Parâmetros de Shan-Chen
gA = -4.7  # força de auto-interação do fluido A
gB = 0.  # força de auto-interação do fluido B (usado apenas se nfluids = 2)
gAB = 6.  # força de interação dos fluidos A e B (usado apenas se nfluids = 2)
rho0 = 1.  # densidade de referência para o potencial pseudo (geralmente definido como 1)
rhol = 2.1  # densidade inicial do líquido
rhog = 0.15  # densidade inicial do gás
radius = 15.  # raio inicial da gota

# Parâmetros fixos; NÃO ALTERAR
npop = 9  # número de populações
cx =[0, 1, 0, -1, 0, 1, -1, -1, 1] # componentes x dos vetores do lattice
cy =[0, 0, 1,  0, -1, 1,  1, -1, -1]  # componentes y dos vetores do lattice
weight = [4./9., 1./9., 1./9., 1./9., 1./9., 1./36., 1./36., 1./36., 1./36.]


# Matrizes
g = np.zeros((nfluids, nfluids))  # forças de interação
rho = np.zeros((nfluids, nx, ny))  # densidade
press = np.zeros((nx, ny))  # pressão
ux = np.zeros((nx, ny))  # componente x da velocidade do fluido
uy = np.zeros((nx, ny))  # componente y da velocidade do fluido
psi_s = np.zeros((nx, ny))  # paralelizando calculos
psi_ss = np.zeros((nx, ny))  # paralelizando calculos
psinb = np.zeros((nx, ny))  # paralelizando calculos
# fxtemp=np.zeros((nx, ny))  # paralelizando calculos
# fytemp=np.zeros((nx, ny))  # paralelizando calculos
Fx = np.zeros((nfluids, nx, ny))  # componente x da força de Shan-Chen
Fy = np.zeros((nfluids, nx, ny))  # componente y da força de Shan-Chen
feq = np.zeros((nfluids, npop))  # populações de equilíbrio
forcing = np.zeros((nfluids, npop))  # populações de força
tau = np.zeros(nfluids)  # tempos de relaxação
f1 = np.zeros((nfluids, nx, ny, npop))  # populações (antigo)
f2 = np.zeros((nfluids, nx, ny, npop))  # populações (novo)
fraction_fluid=0.5  ## fração de fluido

output_dir = os.path.join(os.path.expanduser("~"), "Documents", "PraticaLBM","Densidades")
os.makedirs(output_dir, exist_ok=True)


# Função para computar a densidade em todos os pontos

def compute_density(pop):
    global rho
    rho = np.zeros((nfluids, nx, ny))  # A matriz de densidade já é inicializada fora da função
    for s in range(nfluids):
        rho[s] = np.sum(pop, axis=3).reshape(nx, ny)  # Soma todas as direções em cada nó


def computePressure():
    # Inicializa a matriz de pressão com zeros
    press.fill(0.0)
    
    # Calcula o termo de correção de forma vetorizada
    for s in range(nfluids):
        press += rho[s] / 3.0
        for ss in range(nfluids):
            press += (g[s, ss] * 
                      psi(rho[s]) * 
                      psi(rho[ss]) / 6.0)

def psi(densities):
    return rho0 * (1 - np.exp(-densities / rho0))
                    

def computeSCForces():
    # Inicializa as forças SC
    Fx.fill(0.0)
    Fy.fill(0.0)
    xvet=np.arange(nx)
    x2=np.zeros((nx,npop))
    yvet=np.arange(ny)
    y2=np.zeros((ny,npop))
    for x in range(nx):
        for i in range(npop):
            x2[x,i]=xvet[(x + cx[i]) % nx]
            y2[x,i]=yvet[(x + cy[i]) % ny]  ##como y=x nesse caso, usamos o mesmo loop
    # Computa as forças de Shan-Chen (SC)
    for x in range(nx):
        for y in range(ny):
            for s in range(nfluids):
                for ss in range(nfluids):
                    fxtemp=0
                    fytemp=0
                    for i in range(1, npop):  # Ignorar i=0 (sem força)
                        ##fx e fy temp tavam aqui
                        x2var=int(x2[x,i])
                        y2var=int(y2[y,i])
                        psinb[x,y] = rho0 * (1 - np.exp(-rho[s,x2var,y2var] / rho0))  # Psi do vizinho
                        fxtemp += weight[i] * cx[i] * psinb[x,y]
                        fytemp += weight[i] * cy[i] * psinb[x,y]
                        
                    psiloc = rho0 * (1 - np.exp(-rho[s,x,y] / rho0)) # Psi local
                    Fx[s, x, y] -= g[s, ss] * psiloc * fxtemp
                    Fy[s, x, y] -= g[s, ss] * psiloc * fytemp

    
def computeTotalDensity(x, y):
    # Soma a densidade de todos os fluidos no ponto (x, y)
    return np.sum(rho[:, x, y])


def computePressure():
    # Inicializa a pressão
    press.fill(0.0)
    psi_s = rho0 * (1 - np.exp(-rho / rho0))  # Calcula psi para todos os fluidos de uma vez
    psi_ss = psi_s  # psi_ss é o mesmo que psi_s, já que a operação é simétrica
    press[:, :] += np.sum(rho, axis=0) / 3.0  # Soma as densidades divididas por 3.0

    # Soma contribuições para a pressão com operações vetorizadas
    press[:, :] += np.sum(g[:, :, None, None] * psi_s[:, None, :, :] * psi_ss[None, :, :, :], axis=(0, 1)) / 6.0
                    
def computeVelocity(pop):
    ux.fill(0.0)
    uy.fill(0.0)
    for s in range(nfluids):
        # Calcula contribuições da população
        ux[:,:] += (pop[s, :, :, 1] - pop[s, :, :, 3] +
                     pop[s, :, :, 5] - pop[s, :, :, 6] -
                     pop[s, :, :, 7] + pop[s, :, :, 8])

        uy[:, :] += (pop[s, :, :, 2] - pop[s, :, :, 4] +
                     pop[s, :, :, 5] + pop[s, :, :, 6] -
                     pop[s, :, :, 7] - pop[s, :, :, 8])

        # Adiciona força
        ux[:, :] += 0.5 * Fx[s, :, :]
        uy[:, :] += 0.5 * Fy[s, :, :]

# Normaliza pela densidade total
    for x in range(nx):
        for y in range(ny):
            dens = computeTotalDensity(x,y)
            ux[x, y] /= dens
            uy[x, y] /= dens

            

def equilibrium(s,x,y):
    dens = rho[s,x,y]
    vx = ux[x,y]
    vy = uy[x,y]
    usq = vx * vx + vy * vy
  
    feq[s][0] = weight[0] * dens * (1. - 1.5 * usq)
    feq[s][1] = weight[1] * dens * (1. + 3. * vx + 4.5 * vx * vx - 1.5 * usq)
    feq[s][2] = weight[2] * dens * (1. + 3. * vy + 4.5 * vy * vy - 1.5 * usq)
    feq[s][3] = weight[3] * dens * (1. - 3. * vx + 4.5 * vx * vx - 1.5 * usq)
    feq[s][4] = weight[4] * dens * (1. - 3. * vy + 4.5 * vy * vy - 1.5 * usq)
    feq[s][5] = weight[5] * dens * (1. + 3. * ( vx + vy) + 4.5 * ( vx + vy) * ( vx + vy) - 1.5 * usq)
    feq[s][6] = weight[6] * dens * (1. + 3. * (-vx + vy) + 4.5 * (-vx + vy) * (-vx + vy) - 1.5 * usq)
    feq[s][7] = weight[7] * dens * (1. + 3. * (-vx - vy) + 4.5 * ( vx + vy) * ( vx + vy) - 1.5 * usq)
    feq[s][8] = weight[8] * dens * (1. + 3. * ( vx - vy) + 4.5 * ( vx - vy) * ( vx - vy) - 1.5 * usq)
  

  
def initialisation(f1, f2):
    # Definir viscosidade
    tau[0] = tauA
    if nfluids == 2:
        tau[1] = tauB

    # Definir força de interação
    g[0, 0] = gA
    if nfluids == 2:
        g[1, 1] = gB
        g[0, 1] = gAB
        g[1, 0] = gAB

    # Inicialização para 1 fluido
    if nfluids == 1:
        # Gerar uma máscara aleatória para densidades de fluido e gás
        random_mask = np.random.rand(nx, ny) < fraction_fluid
        rho[0] = np.where(random_mask, rhol, rhog)

    # Inicialização para 2 fluidos
    elif nfluids == 2:
        mid_y = ny // 2
        rho[0, :, :mid_y] = 0.1
        rho[1, :, :mid_y] = 0.9
        rho[0, :, mid_y:] = 0.9
        rho[1, :, mid_y:] = 0.1

    # Configurar o campo de velocidade inicial (velocidade zero em todos os lugares)
    ux.fill(0.0)
    uy.fill(0.0)

    # Calcular as distribuições de equilíbrio e inicializar as populações
    for s in range(nfluids):
        for y in range(ny):
            for x in range(nx):
                equilibrium(s, x, y)
                f1[s, x, y, :] = feq[s, :]
                f2[s, x, y, :] = feq[s, :]
                
def push(f1, f2):
    for s in range(nfluids):
        omega = 1.0 / tau[s]

        for x in range(nx):  
            for y in range(ny):  
                for i in range(npop):
                    forcing[s,i] = weight[i] * (1.0 - 0.5 * omega) * \
                        ((3.0 * (cx[i] - ux[x, y]) + 9.0 * cx[i] * (cx[i] * ux[x, y] + cy[i] * uy[x, y])) * Fx[s, x, y] +
                         (3.0 * (cy[i] - uy[x, y]) + 9.0 * cy[i] * (cx[i] * ux[x, y] + cy[i] * uy[x, y])) * Fy[s, x, y])

                # Compute equilibrium distributions
                equilibrium(s, x, y)

                # Collide and propagate
                for i in range(npop):
                    x2 = (x + cx[i] + nx) % nx  # Periodic boundary in x
                    y2 = (y + cy[i] + ny) % ny  # Periodic boundary in y
                    f2[s, x2, y2, i] = f1[s, x, y, i] * (1.0 - omega) + feq[s, i] * omega + forcing[s,i]

    return

                 
# def write_file(name, data, n):
#     #Função auxiliar para salvar dados em disco.
#     name = os.path.expanduser(os.path.join("~", "Documents", "PraticaLBM","Densidades", name))
#     # Verifique se o diretório existe, caso contrário, crie-o
#     os.makedirs(os.path.dirname(name), exist_ok=True)
#     with open(name, "w") as fout:
#         for y in range(ny):
#             for x in range(nx):
#                 fout.write(f"{data[y * nx + x]} ")
#             fout.write("\n")
#         fout.write("\n")

def write_file(name, data, n):
    # Use output_dir para consistência
    file_path = os.path.join(output_dir, name)
    print(file_path)
    os.makedirs(output_dir, exist_ok=True)  # Garantir que o diretório exista
    with open(file_path, "w") as fout:
        for y in range(ny):
            for x in range(nx):
                fout.write(f"{data[y * nx + x]} ")
            fout.write("\n")
        fout.write("\n")


def write_profiles(step):
    """
    Função para salvar os perfis (densidade, pressão, velocidades) no disco.
    """
    # Converter o número do passo em string com zero-padding
    step_str = str(step).zfill(5)

    # Salvar os perfis de pressão e velocidades
    press_filename = f"press_{step_str}.dat"
    velx_filename = f"velx_{step_str}.dat"
    vely_filename = f"vely_{step_str}.dat"

    write_file(press_filename, press, nx * ny)
    write_file(velx_filename, ux, nx * ny)
    write_file(vely_filename, uy, nx * ny)

    # Salvar os perfis de densidade para cada componente de fluido
    for s in range(nfluids):
        density_filename = f"density_comp{s}_{step_str}.dat"
        write_file(density_filename, rho[s], nx * ny)


def calculate_delta_pressure():
    """
    Calcula a pressão de Laplace e imprime densidades, diferenças de pressão, 
    raio da gota e tensão superficial.
    """
    rho_gas = 0.0
    rho_liq = 0.0
    press_gas = 0.0
    press_liq = 0.0

    # Pressão média do gás em um quadrado de 4 nós de malha
    for x in range(4):
        for y in range(4):
            rho_gas += rho[0,x,y]
            press_gas += press[x,y]

    # Pressão média do líquido em um quadrado de 4 nós de malha no centro
    for x in range(nx // 2 - 2, nx // 2 + 2):
        for y in range(ny // 2 - 2, ny // 2 + 2):
            rho_liq += rho[0,x,y]
            press_liq += press[x,y]

    # Calcula médias
    rho_gas /= 16.0
    rho_liq /= 16.0
    press_gas /= 16.0
    press_liq /= 16.0

    # Diferença de pressão e densidade média
    delta_press = press_liq - press_gas
    rho_av = 0.5 * (rho_gas + rho_liq)
    y = ny // 2
    rad = None

    # Determina o raio da gota
    for x in range(nx // 2):
        if rho[0,x,y] > rho_av:
            drho = rho[0,x,y] - rho[0,x-1,y]
            dx = (rho_av - rho[0,x-1,y]) / drho
            rad = (nx / 2.0 - x) + (1.0 - dx)
            break

    # Calcula a tensão superficial
    gamma = delta_press * rad

    # Imprime os resultados
    print(f"  Densities: rho_g = {rho_gas}, rho_l = {rho_liq}")
    print(f"  Pressure difference: dp = {delta_press}")
    print(f"  Droplet radius: r = {rad}")
    print(f"  Surface tension: gamma = {gamma}")

    return


# Função para imprimir status, fora do Numba
def print_status(step, elapsed_time):
    print("Running time step {}".format(step))
    print("Overall CPU time required: {:.2f} sec".format(elapsed_time))
    mlups = nx * ny * nsteps / (elapsed_time * 1e6)
    print("This corresponds to {:.2f} MLUPS".format(mlups))

# Função para criar animação, fora do Numba
def create_animation(output_dir):
    with imageio.get_writer("densidade_animacao.gif", mode="I", duration=0.1) as writer:
        frame_files = sorted(glob.glob("{}frame_*.png".format(output_dir)))  # Ordena os frames corretamente
        for filename in frame_files:
            image = imageio.imread(filename)
            writer.append_data(image)

    print("Animação salva como 'densidade_animacao.gif'")

def main():
    # Configurar cronômetro da simulação
    start = time.time()

    # Alocar memória para populações
    f1 = np.zeros((nfluids, nx, ny, npop))  # Populações antigas
    f2 = np.zeros((nfluids, nx, ny, npop))  # Populações novas
    # Inicializar domínio
    initialisation(f1, f2)

    # Loop principal
    for step in range(nsteps + 1):
        # Calcular campo de densidade
        compute_density(f1)

        # Calcular forças SC
        computeSCForces()

        # Calcular velocidade baricêntrica
        computeVelocity(f1)

        # Colidir e propagar
        push(f1, f2)

        # Trocar populações antigas e novas
        f1, f2 = f2, f1

        # Escrever dados em disco/console
        if step % noutput == 0:
            print_status(step, time.time() - start)
            computePressure()
            #write_profiles(step)
            #calculate_delta_pressure()
            rho_summed = np.einsum('sxy->xy', rho)
            rho_matriz = rho_summed.reshape(nx, ny)
            plt.figure(figsize=(6, 6))
            plt.imshow(rho_matriz, cmap="viridis", origin="lower")
            plt.colorbar(label="Densidade")
            plt.title("Frame {}".format(step))
#             plt.savefig("{}frame_{:03d}.png".format(output_dir, int(step / 10)))
            plt.savefig(os.path.join(output_dir, "frame_{:03d}.png".format(int(step / 10))))
            print(output_dir)
            plt.close()

    # Exibir estatísticas de desempenho
    finish = time.time()
    elapsed_time = finish - start
    print_status(nsteps, elapsed_time)  # Imprimir estatísticas no final

# Chamar a função principal
if __name__ == "__main__":
    main()

#Criar animação após a execução do cálculo
create_animation(output_dir)

### CODIGO MODIFICADO PARA INICIALIZAÇÃO ALEATÓRIA
# Out:
# Running time step 0
# Overall CPU time required: 0.27 sec
# This corresponds to 30.72 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 5
# Overall CPU time required: 1.54 sec
# This corresponds to 5.31 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 10
# Overall CPU time required: 2.77 sec
# This corresponds to 2.96 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 15
# Overall CPU time required: 4.00 sec
# This corresponds to 2.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 20
# Overall CPU time required: 5.23 sec
# This corresponds to 1.57 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 25
# Overall CPU time required: 6.54 sec
# This corresponds to 1.25 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 30
# Overall CPU time required: 7.80 sec
# This corresponds to 1.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 35
# Overall CPU time required: 9.10 sec
# This corresponds to 0.90 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 40
# Overall CPU time required: 10.46 sec
# This corresponds to 0.78 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 45
# Overall CPU time required: 11.83 sec
# This corresponds to 0.69 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 50
# Overall CPU time required: 13.21 sec
# This corresponds to 0.62 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 55
# Overall CPU time required: 14.62 sec
# This corresponds to 0.56 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 60
# Overall CPU time required: 15.98 sec
# This corresponds to 0.51 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 65
# Overall CPU time required: 17.34 sec
# This corresponds to 0.47 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 70
# Overall CPU time required: 18.67 sec
# This corresponds to 0.44 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 75
# Overall CPU time required: 20.01 sec
# This corresponds to 0.41 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 80
# Overall CPU time required: 21.30 sec
# This corresponds to 0.38 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 85
# Overall CPU time required: 22.58 sec
# This corresponds to 0.36 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 90
# Overall CPU time required: 23.83 sec
# This corresponds to 0.34 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 95
# Overall CPU time required: 25.11 sec
# This corresponds to 0.33 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 100
# Overall CPU time required: 26.39 sec
# This corresponds to 0.31 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 105
# Overall CPU time required: 27.71 sec
# This corresponds to 0.30 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 110
# Overall CPU time required: 29.00 sec
# This corresponds to 0.28 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 115
# Overall CPU time required: 30.32 sec
# This corresponds to 0.27 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 120
# Overall CPU time required: 31.59 sec
# This corresponds to 0.26 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 125
# Overall CPU time required: 32.94 sec
# This corresponds to 0.25 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 130
# Overall CPU time required: 34.17 sec
# This corresponds to 0.24 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 135
# Overall CPU time required: 35.44 sec
# This corresponds to 0.23 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 140
# Overall CPU time required: 36.69 sec
# This corresponds to 0.22 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 145
# Overall CPU time required: 37.97 sec
# This corresponds to 0.22 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 150
# Overall CPU time required: 39.23 sec
# This corresponds to 0.21 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 155
# Overall CPU time required: 40.47 sec
# This corresponds to 0.20 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 160
# Overall CPU time required: 41.74 sec
# This corresponds to 0.20 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 165
# Overall CPU time required: 43.00 sec
# This corresponds to 0.19 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 170
# Overall CPU time required: 44.24 sec
# This corresponds to 0.19 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 175
# Overall CPU time required: 45.50 sec
# This corresponds to 0.18 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 180
# Overall CPU time required: 46.77 sec
# This corresponds to 0.18 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 185
# Overall CPU time required: 48.02 sec
# This corresponds to 0.17 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 190
# Overall CPU time required: 49.28 sec
# This corresponds to 0.17 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 195
# Overall CPU time required: 50.55 sec
# This corresponds to 0.16 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 200
# Overall CPU time required: 51.79 sec
# This corresponds to 0.16 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 205
# Overall CPU time required: 53.15 sec
# This corresponds to 0.15 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 210
# Overall CPU time required: 54.38 sec
# This corresponds to 0.15 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 215
# Overall CPU time required: 55.65 sec
# This corresponds to 0.15 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 220
# Overall CPU time required: 56.90 sec
# This corresponds to 0.14 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 225
# Overall CPU time required: 58.14 sec
# This corresponds to 0.14 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 230
# Overall CPU time required: 59.37 sec
# This corresponds to 0.14 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 235
# Overall CPU time required: 60.72 sec
# This corresponds to 0.13 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 240
# Overall CPU time required: 61.99 sec
# This corresponds to 0.13 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 245
# Overall CPU time required: 63.20 sec
# This corresponds to 0.13 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 250
# Overall CPU time required: 64.41 sec
# This corresponds to 0.13 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 255
# Overall CPU time required: 65.68 sec
# This corresponds to 0.12 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 260
# Overall CPU time required: 66.91 sec
# This corresponds to 0.12 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 265
# Overall CPU time required: 68.12 sec
# This corresponds to 0.12 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 270
# Overall CPU time required: 69.35 sec
# This corresponds to 0.12 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 275
# Overall CPU time required: 70.59 sec
# This corresponds to 0.12 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 280
# Overall CPU time required: 71.80 sec
# This corresponds to 0.11 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 285
# Overall CPU time required: 73.02 sec
# This corresponds to 0.11 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 290
# Overall CPU time required: 74.24 sec
# This corresponds to 0.11 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 295
# Overall CPU time required: 75.49 sec
# This corresponds to 0.11 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 300
# Overall CPU time required: 76.77 sec
# This corresponds to 0.11 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 305
# Overall CPU time required: 78.01 sec
# This corresponds to 0.11 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 310
# Overall CPU time required: 79.21 sec
# This corresponds to 0.10 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 315
# Overall CPU time required: 80.62 sec
# This corresponds to 0.10 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 320
# Overall CPU time required: 81.86 sec
# This corresponds to 0.10 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 325
# Overall CPU time required: 83.10 sec
# This corresponds to 0.10 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 330
# Overall CPU time required: 84.33 sec
# This corresponds to 0.10 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 335
# Overall CPU time required: 85.56 sec
# This corresponds to 0.10 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 340
# Overall CPU time required: 86.81 sec
# This corresponds to 0.09 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 345
# Overall CPU time required: 88.04 sec
# This corresponds to 0.09 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 350
# Overall CPU time required: 89.28 sec
# This corresponds to 0.09 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 355
# Overall CPU time required: 90.52 sec
# This corresponds to 0.09 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 360
# Overall CPU time required: 91.75 sec
# This corresponds to 0.09 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 365
# Overall CPU time required: 93.00 sec
# This corresponds to 0.09 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 370
# Overall CPU time required: 94.25 sec
# This corresponds to 0.09 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 375
# Overall CPU time required: 95.51 sec
# This corresponds to 0.09 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 380
# Overall CPU time required: 96.73 sec
# This corresponds to 0.08 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 385
# Overall CPU time required: 98.02 sec
# This corresponds to 0.08 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 390
# Overall CPU time required: 99.23 sec
# This corresponds to 0.08 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 395
# Overall CPU time required: 100.49 sec
# This corresponds to 0.08 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 400
# Overall CPU time required: 101.72 sec
# This corresponds to 0.08 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 405
# Overall CPU time required: 103.00 sec
# This corresponds to 0.08 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 410
# Overall CPU time required: 104.24 sec
# This corresponds to 0.08 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 415
# Overall CPU time required: 105.49 sec
# This corresponds to 0.08 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 420
# Overall CPU time required: 106.72 sec
# This corresponds to 0.08 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 425
# Overall CPU time required: 107.98 sec
# This corresponds to 0.08 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 430
# Overall CPU time required: 109.19 sec
# This corresponds to 0.08 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 435
# Overall CPU time required: 110.44 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 440
# Overall CPU time required: 111.64 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 445
# Overall CPU time required: 113.03 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 450
# Overall CPU time required: 114.29 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 455
# Overall CPU time required: 115.53 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 460
# Overall CPU time required: 116.75 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 465
# Overall CPU time required: 117.95 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 470
# Overall CPU time required: 119.22 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 475
# Overall CPU time required: 120.49 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 480
# Overall CPU time required: 121.68 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 485
# Overall CPU time required: 122.93 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 490
# Overall CPU time required: 124.14 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 495
# Overall CPU time required: 125.37 sec
# This corresponds to 0.07 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 500
# Overall CPU time required: 126.59 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 505
# Overall CPU time required: 127.83 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 510
# Overall CPU time required: 129.05 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 515
# Overall CPU time required: 130.29 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 520
# Overall CPU time required: 131.50 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 525
# Overall CPU time required: 132.71 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 530
# Overall CPU time required: 133.95 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 535
# Overall CPU time required: 135.17 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 540
# Overall CPU time required: 136.36 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 545
# Overall CPU time required: 137.60 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 550
# Overall CPU time required: 138.83 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 555
# Overall CPU time required: 140.03 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 560
# Overall CPU time required: 141.23 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 565
# Overall CPU time required: 142.43 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 570
# Overall CPU time required: 143.63 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 575
# Overall CPU time required: 144.83 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 580
# Overall CPU time required: 146.03 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 585
# Overall CPU time required: 147.23 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 590
# Overall CPU time required: 148.42 sec
# This corresponds to 0.06 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 595
# Overall CPU time required: 149.69 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 600
# Overall CPU time required: 150.93 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 605
# Overall CPU time required: 152.16 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 610
# Overall CPU time required: 153.56 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 615
# Overall CPU time required: 154.80 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 620
# Overall CPU time required: 155.99 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 625
# Overall CPU time required: 157.22 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 630
# Overall CPU time required: 158.40 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 635
# Overall CPU time required: 159.60 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 640
# Overall CPU time required: 160.79 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 645
# Overall CPU time required: 161.99 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 650
# Overall CPU time required: 163.24 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 655
# Overall CPU time required: 164.52 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 660
# Overall CPU time required: 165.75 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 665
# Overall CPU time required: 166.97 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 670
# Overall CPU time required: 168.22 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 675
# Overall CPU time required: 169.43 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 680
# Overall CPU time required: 170.65 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 685
# Overall CPU time required: 171.87 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 690
# Overall CPU time required: 173.06 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 695
# Overall CPU time required: 174.28 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 700
# Overall CPU time required: 175.53 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 705
# Overall CPU time required: 176.77 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 710
# Overall CPU time required: 177.99 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 715
# Overall CPU time required: 179.19 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 720
# Overall CPU time required: 180.41 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 725
# Overall CPU time required: 181.62 sec
# This corresponds to 0.05 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 730
# Overall CPU time required: 182.81 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 735
# Overall CPU time required: 184.01 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 740
# Overall CPU time required: 185.20 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 745
# Overall CPU time required: 186.40 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 750
# Overall CPU time required: 187.58 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 755
# Overall CPU time required: 188.78 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 760
# Overall CPU time required: 189.97 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 765
# Overall CPU time required: 191.18 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 770
# Overall CPU time required: 192.37 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 775
# Overall CPU time required: 193.57 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 780
# Overall CPU time required: 194.76 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 785
# Overall CPU time required: 195.97 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 790
# Overall CPU time required: 197.18 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 795
# Overall CPU time required: 198.38 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 800
# Overall CPU time required: 199.57 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 805
# Overall CPU time required: 200.79 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 810
# Overall CPU time required: 201.98 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 815
# Overall CPU time required: 203.43 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 820
# Overall CPU time required: 204.64 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 825
# Overall CPU time required: 205.93 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 830
# Overall CPU time required: 207.13 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 835
# Overall CPU time required: 208.35 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 840
# Overall CPU time required: 209.58 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 845
# Overall CPU time required: 210.78 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 850
# Overall CPU time required: 211.97 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 855
# Overall CPU time required: 213.18 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 860
# Overall CPU time required: 214.41 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 865
# Overall CPU time required: 215.64 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 870
# Overall CPU time required: 216.83 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 875
# Overall CPU time required: 218.03 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 880
# Overall CPU time required: 219.22 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 885
# Overall CPU time required: 220.42 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 890
# Overall CPU time required: 221.62 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 895
# Overall CPU time required: 222.88 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 900
# Overall CPU time required: 224.16 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 905
# Overall CPU time required: 225.45 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 910
# Overall CPU time required: 226.68 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 915
# Overall CPU time required: 227.92 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 920
# Overall CPU time required: 229.11 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 925
# Overall CPU time required: 230.31 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 930
# Overall CPU time required: 231.50 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 935
# Overall CPU time required: 232.70 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 940
# Overall CPU time required: 233.90 sec
# This corresponds to 0.04 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 945
# Overall CPU time required: 235.10 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 950
# Overall CPU time required: 236.29 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 955
# Overall CPU time required: 237.50 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 960
# Overall CPU time required: 238.69 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 965
# Overall CPU time required: 239.89 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 970
# Overall CPU time required: 241.08 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 975
# Overall CPU time required: 242.29 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 980
# Overall CPU time required: 243.48 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 985
# Overall CPU time required: 244.68 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 990
# Overall CPU time required: 245.87 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 995
# Overall CPU time required: 247.07 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1000
# Overall CPU time required: 248.28 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1005
# Overall CPU time required: 249.48 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1010
# Overall CPU time required: 250.67 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1015
# Overall CPU time required: 251.87 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1020
# Overall CPU time required: 253.06 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1025
# Overall CPU time required: 254.27 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1030
# Overall CPU time required: 255.48 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1035
# Overall CPU time required: 256.69 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1040
# Overall CPU time required: 257.88 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1045
# Overall CPU time required: 259.08 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1050
# Overall CPU time required: 260.27 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1055
# Overall CPU time required: 261.47 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1060
# Overall CPU time required: 262.66 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1065
# Overall CPU time required: 263.86 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1070
# Overall CPU time required: 265.36 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1075
# Overall CPU time required: 266.56 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1080
# Overall CPU time required: 267.75 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1085
# Overall CPU time required: 268.94 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1090
# Overall CPU time required: 270.13 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1095
# Overall CPU time required: 271.33 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1100
# Overall CPU time required: 272.52 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1105
# Overall CPU time required: 273.71 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1110
# Overall CPU time required: 274.90 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1115
# Overall CPU time required: 276.10 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1120
# Overall CPU time required: 277.29 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1125
# Overall CPU time required: 278.50 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1130
# Overall CPU time required: 279.69 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1135
# Overall CPU time required: 280.89 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1140
# Overall CPU time required: 282.08 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1145
# Overall CPU time required: 283.31 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1150
# Overall CPU time required: 284.50 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1155
# Overall CPU time required: 285.70 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1160
# Overall CPU time required: 286.89 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1165
# Overall CPU time required: 288.09 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1170
# Overall CPU time required: 289.29 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1175
# Overall CPU time required: 290.57 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1180
# Overall CPU time required: 291.87 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1185
# Overall CPU time required: 293.08 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1190
# Overall CPU time required: 294.32 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1195
# Overall CPU time required: 295.56 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1200
# Overall CPU time required: 296.81 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1205
# Overall CPU time required: 298.08 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1210
# Overall CPU time required: 299.33 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1215
# Overall CPU time required: 300.61 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1220
# Overall CPU time required: 301.84 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1225
# Overall CPU time required: 303.08 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1230
# Overall CPU time required: 304.31 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1235
# Overall CPU time required: 305.53 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1240
# Overall CPU time required: 306.82 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1245
# Overall CPU time required: 308.04 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1250
# Overall CPU time required: 309.26 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1255
# Overall CPU time required: 310.46 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1260
# Overall CPU time required: 311.65 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1265
# Overall CPU time required: 312.89 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1270
# Overall CPU time required: 314.13 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1275
# Overall CPU time required: 315.37 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1280
# Overall CPU time required: 316.58 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1285
# Overall CPU time required: 317.82 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1290
# Overall CPU time required: 319.01 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1295
# Overall CPU time required: 320.21 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1300
# Overall CPU time required: 321.41 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1305
# Overall CPU time required: 322.62 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1310
# Overall CPU time required: 323.81 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1315
# Overall CPU time required: 325.01 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1320
# Overall CPU time required: 326.20 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1325
# Overall CPU time required: 327.39 sec
# This corresponds to 0.03 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1330
# Overall CPU time required: 328.60 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1335
# Overall CPU time required: 329.80 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1340
# Overall CPU time required: 331.00 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1345
# Overall CPU time required: 332.20 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1350
# Overall CPU time required: 333.39 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1355
# Overall CPU time required: 334.61 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1360
# Overall CPU time required: 335.88 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1365
# Overall CPU time required: 337.12 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1370
# Overall CPU time required: 338.37 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1375
# Overall CPU time required: 339.60 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1380
# Overall CPU time required: 340.83 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1385
# Overall CPU time required: 342.43 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1390
# Overall CPU time required: 343.64 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1395
# Overall CPU time required: 344.86 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1400
# Overall CPU time required: 346.07 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1405
# Overall CPU time required: 347.30 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1410
# Overall CPU time required: 348.55 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1415
# Overall CPU time required: 349.79 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1420
# Overall CPU time required: 351.03 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1425
# Overall CPU time required: 352.23 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1430
# Overall CPU time required: 353.45 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1435
# Overall CPU time required: 354.79 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1440
# Overall CPU time required: 356.00 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1445
# Overall CPU time required: 357.25 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1450
# Overall CPU time required: 358.44 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1455
# Overall CPU time required: 359.65 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1460
# Overall CPU time required: 360.85 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1465
# Overall CPU time required: 362.10 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1470
# Overall CPU time required: 363.32 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1475
# Overall CPU time required: 364.56 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1480
# Overall CPU time required: 365.81 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1485
# Overall CPU time required: 367.01 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1490
# Overall CPU time required: 368.29 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1495
# Overall CPU time required: 369.50 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1500
# Overall CPU time required: 370.71 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1505
# Overall CPU time required: 371.91 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1510
# Overall CPU time required: 373.16 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1515
# Overall CPU time required: 374.36 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1520
# Overall CPU time required: 375.56 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1525
# Overall CPU time required: 376.75 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1530
# Overall CPU time required: 377.97 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1535
# Overall CPU time required: 379.21 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1540
# Overall CPU time required: 380.43 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1545
# Overall CPU time required: 381.63 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1550
# Overall CPU time required: 382.81 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1555
# Overall CPU time required: 384.01 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1560
# Overall CPU time required: 385.20 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1565
# Overall CPU time required: 386.40 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1570
# Overall CPU time required: 387.59 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1575
# Overall CPU time required: 388.79 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1580
# Overall CPU time required: 389.99 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1585
# Overall CPU time required: 391.19 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1590
# Overall CPU time required: 392.40 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1595
# Overall CPU time required: 393.67 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1600
# Overall CPU time required: 394.92 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1605
# Overall CPU time required: 396.13 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1610
# Overall CPU time required: 397.41 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1615
# Overall CPU time required: 398.63 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1620
# Overall CPU time required: 399.84 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1625
# Overall CPU time required: 401.10 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1630
# Overall CPU time required: 402.31 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1635
# Overall CPU time required: 403.54 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1640
# Overall CPU time required: 404.73 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1645
# Overall CPU time required: 405.94 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1650
# Overall CPU time required: 407.15 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1655
# Overall CPU time required: 408.37 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1660
# Overall CPU time required: 409.57 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1665
# Overall CPU time required: 410.78 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1670
# Overall CPU time required: 411.97 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1675
# Overall CPU time required: 413.17 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1680
# Overall CPU time required: 414.37 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1685
# Overall CPU time required: 415.59 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1690
# Overall CPU time required: 416.78 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1695
# Overall CPU time required: 418.05 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1700
# Overall CPU time required: 419.26 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1705
# Overall CPU time required: 420.50 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1710
# Overall CPU time required: 421.78 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1715
# Overall CPU time required: 423.05 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1720
# Overall CPU time required: 424.28 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1725
# Overall CPU time required: 425.53 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1730
# Overall CPU time required: 426.78 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1735
# Overall CPU time required: 428.04 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1740
# Overall CPU time required: 429.31 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1745
# Overall CPU time required: 430.65 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1750
# Overall CPU time required: 431.89 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1755
# Overall CPU time required: 433.15 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1760
# Overall CPU time required: 434.40 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1765
# Overall CPU time required: 435.61 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1770
# Overall CPU time required: 436.86 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1775
# Overall CPU time required: 438.55 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1780
# Overall CPU time required: 439.75 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1785
# Overall CPU time required: 440.94 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1790
# Overall CPU time required: 442.14 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1795
# Overall CPU time required: 443.33 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1800
# Overall CPU time required: 444.54 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1805
# Overall CPU time required: 445.74 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1810
# Overall CPU time required: 446.94 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1815
# Overall CPU time required: 448.14 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1820
# Overall CPU time required: 449.34 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1825
# Overall CPU time required: 450.54 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1830
# Overall CPU time required: 451.75 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1835
# Overall CPU time required: 452.95 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1840
# Overall CPU time required: 454.18 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1845
# Overall CPU time required: 455.40 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1850
# Overall CPU time required: 456.60 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1855
# Overall CPU time required: 457.80 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1860
# Overall CPU time required: 459.02 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1865
# Overall CPU time required: 460.26 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1870
# Overall CPU time required: 461.49 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1875
# Overall CPU time required: 462.69 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1880
# Overall CPU time required: 463.89 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1885
# Overall CPU time required: 465.09 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1890
# Overall CPU time required: 466.29 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1895
# Overall CPU time required: 467.49 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1900
# Overall CPU time required: 468.70 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1905
# Overall CPU time required: 469.94 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1910
# Overall CPU time required: 471.16 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1915
# Overall CPU time required: 472.41 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1920
# Overall CPU time required: 473.63 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1925
# Overall CPU time required: 474.88 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1930
# Overall CPU time required: 476.11 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1935
# Overall CPU time required: 477.31 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1940
# Overall CPU time required: 478.53 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1945
# Overall CPU time required: 479.80 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1950
# Overall CPU time required: 481.00 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1955
# Overall CPU time required: 482.20 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1960
# Overall CPU time required: 483.49 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1965
# Overall CPU time required: 484.72 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1970
# Overall CPU time required: 485.96 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1975
# Overall CPU time required: 487.18 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1980
# Overall CPU time required: 488.37 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1985
# Overall CPU time required: 489.60 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1990
# Overall CPU time required: 490.81 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 1995
# Overall CPU time required: 492.03 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 2000
# Overall CPU time required: 493.23 sec
# This corresponds to 0.02 MLUPS
# /home/joao/Documents/PraticaLBM/Densidades
# Running time step 2000
# Overall CPU time required: 493.34 sec
# This corresponds to 0.02 MLUPS
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 408
#     405     main()
#     407 #Criar animação após a execução do cálculo
# --> 408 create_animation(output_dir)
#     410 ### CODIGO MODIFICADO PARA INICIALIZAÇÃO ALEATÓRIA
#
# Cell In[13], line 346, in create_animation(output_dir)
#     345 def create_animation(output_dir):
# --> 346     with imageio.get_writer("densidade_animacao.gif", mode="I", duration=0.1) as writer:
#     347         frame_files = sorted(glob.glob("{}frame_*.png".format(output_dir)))  # Ordena os frames corretamente
#     348         for filename in frame_files:
#
# NameError: name 'imageio' is not defined

# %%
import numpy as np
import os
import time
import matplotlib.pyplot as plt


# Parâmetros do lattice
nx = 64  # número de nós ao longo do eixo x
ny = 64  # número de nós ao longo do eixo y
nsteps = 2000  # número de passos de tempo
noutput = 100  # intervalo de saída de dados (dados escritos em "/data")
nfluids = 2  # número de componentes do fluido (escolha 1 ou 2)
tauA = 1  # tempo de relaxação para o fluido A
tauB = 1  # tempo de relaxação para o fluido B (usado apenas se nfluids = 2)

# Parâmetros de Shan-Chen
gA = -4.7  # força de auto-interação do fluido A
gB = -4.7  # força de auto-interação do fluido B (usado apenas se nfluids = 2)
gAB = 6.  # força de interação dos fluidos A e B (usado apenas se nfluids = 2)
rho0 = 1.  # densidade de referência para o potencial pseudo (geralmente definido como 1)
rhol = 2.1  # densidade inicial do líquido
rhog = 0.15  # densidade inicial do gás
radius = 15.  # raio inicial da gota

# Parâmetros fixos; NÃO ALTERAR
npop = 9  # número de populações
cx =[0, 1, 0, -1, 0, 1, -1, -1, 1] # componentes x dos vetores do lattice
cy =[0, 0, 1,  0, -1, 1,  1, -1, -1]  # componentes y dos vetores do lattice
weight = [4./9., 1./9., 1./9., 1./9., 1./9., 1./36., 1./36., 1./36., 1./36.]


# Matrizes
g = np.zeros((nfluids, nfluids))  # forças de interação
rho = np.zeros((nfluids, nx, ny))  # densidade
press = np.zeros((nx, ny))  # pressão
ux = np.zeros((nx, ny))  # componente x da velocidade do fluido
uy = np.zeros((nx, ny))  # componente y da velocidade do fluido
psi_s = np.zeros((nx, ny))  # paralelizando calculos
psi_ss = np.zeros((nx, ny))  # paralelizando calculos
psinb = np.zeros((nx, ny))  # paralelizando calculos
# fxtemp=np.zeros((nx, ny))  # paralelizando calculos
# fytemp=np.zeros((nx, ny))  # paralelizando calculos
Fx = np.zeros((nfluids, nx, ny))  # componente x da força de Shan-Chen
Fy = np.zeros((nfluids, nx, ny))  # componente y da força de Shan-Chen
feq = np.zeros((nfluids, npop))  # populações de equilíbrio
forcing = np.zeros((nfluids, npop))  # populações de força
tau = np.zeros(nfluids)  # tempos de relaxação
f1 = np.zeros((nfluids, nx, ny, npop))  # populações (antigo)
f2 = np.zeros((nfluids, nx, ny, npop))  # populações (novo)

output_dir = os.path.join(os.path.expanduser("~"), "Documents", "PraticaLBM","Densidades")
os.makedirs(output_dir, exist_ok=True)



# Função para computar a densidade em todos os pontos

def compute_density(pop):
    global rho
    rho = np.zeros((nfluids, nx, ny))  # A matriz de densidade já é inicializada fora da função
    rho = np.einsum('sxyp->sxy', pop)

def computePressure():
    # Inicializa a matriz de pressão com zeros
    press.fill(0.0)
    
    # Calcula o termo de correção de forma vetorizada
    for s in range(nfluids):
        press += rho[s] / 3.0
        psi_s=rho0 * (1 - np.exp(-rho[s] / rho0))
        for ss in range(nfluids):
            psi_ss=rho0 * (1 - np.exp(-rho[ss] / rho0))
            press += (g[s, ss]*psi_s*psi_ss / 6.0)

def psi(densities):
    return rho0 * (1 - np.exp(-densities / rho0))
                    

def computeSCForces():
    # Inicializa as forças SC
    Fx.fill(0.0)
    Fy.fill(0.0)
    xvet=np.arange(nx)
    x2=np.zeros((nx,npop))
    yvet=np.arange(ny)
    y2=np.zeros((ny,npop))
    for x in range(nx):
        for i in range(npop):
            x2[x,i]=xvet[(x + cx[i]) % nx]
            y2[x,i]=yvet[(x + cy[i]) % ny]  ##como y=x nesse caso, usamos o mesmo loop
    # Computa as forças de Shan-Chen (SC)
    for x in range(nx):
        for y in range(ny):
            for s in range(nfluids):
                for ss in range(nfluids):
                    fxtemp=0
                    fytemp=0
                    for i in range(1, npop):  # Ignorar i=0 (sem força)
                        ##fx e fy temp tavam aqui
                        x2var=int(x2[x,i])
                        y2var=int(y2[y,i])
                        psinb[x,y] = rho0 * (1 - np.exp(-rho[s,x2var,y2var] / rho0))  # Psi do vizinho
                        fxtemp += weight[i] * cx[i] * psinb[x,y]
                        fytemp += weight[i] * cy[i] * psinb[x,y]                    
                    psiloc = rho0 * (1 - np.exp(-rho[s,x,y] / rho0)) # Psi local
                    Fx[s, x, y] -= g[s, ss] * psiloc * fxtemp
                    Fy[s, x, y] -= g[s, ss] * psiloc * fytemp

    
def computeTotalDensity(x, y):
    # Soma a densidade de todos os fluidos no ponto (x, y)
    return np.sum(rho[:, x, y])


def computePressure():
    # Inicializa a pressão
    psi = rho0 * (1 - np.exp(-rho / rho0))  # Calcula psi para todos os fluidos de uma vez
    press = np.einsum('sxy->xy',rho)/3.0  # Soma as densidades divididas por 3.0

    # Soma contribuições para a pressão com operações vetorizadas
    press[:, :] += np.sum(g[:, :, None, None] * psi[:, None, :, :] * psi[None, :, :, :], axis=(0, 1)) / 6.0
                    


def computeVelocity(pop):
    ux.fill(0.0)
    uy.fill(0.0)
    for s in range(nfluids):
        # Calcula contribuições da população
        ux[:,:] += (pop[s, :, :, 1] - pop[s, :, :, 3] +
                     pop[s, :, :, 5] - pop[s, :, :, 6] -
                     pop[s, :, :, 7] + pop[s, :, :, 8])

        uy[:, :] += (pop[s, :, :, 2] - pop[s, :, :, 4] +
                     pop[s, :, :, 5] + pop[s, :, :, 6] -
                     pop[s, :, :, 7] - pop[s, :, :, 8])

        # Adiciona força
        ux[:, :] += 0.5 * Fx[s, :, :]
        uy[:, :] += 0.5 * Fy[s, :, :]

# Normaliza pela densidade total
    for x in range(nx):
        for y in range(ny):
            dens = computeTotalDensity(x,y)
            ux[x, y] /= dens
            uy[x, y] /= dens

            

def equilibrium(s,x,y):
    dens = rho[s,x,y]
    vx = ux[x,y]
    vy = uy[x,y]
    usq = vx * vx + vy * vy
  
    feq[s][0] = weight[0] * dens * (1. - 1.5 * usq)
    feq[s][1] = weight[1] * dens * (1. + 3. * vx + 4.5 * vx * vx - 1.5 * usq)
    feq[s][2] = weight[2] * dens * (1. + 3. * vy + 4.5 * vy * vy - 1.5 * usq)
    feq[s][3] = weight[3] * dens * (1. - 3. * vx + 4.5 * vx * vx - 1.5 * usq)
    feq[s][4] = weight[4] * dens * (1. - 3. * vy + 4.5 * vy * vy - 1.5 * usq)
    feq[s][5] = weight[5] * dens * (1. + 3. * ( vx + vy) + 4.5 * ( vx + vy) * ( vx + vy) - 1.5 * usq)
    feq[s][6] = weight[6] * dens * (1. + 3. * (-vx + vy) + 4.5 * (-vx + vy) * (-vx + vy) - 1.5 * usq)
    feq[s][7] = weight[7] * dens * (1. + 3. * (-vx - vy) + 4.5 * ( vx + vy) * ( vx + vy) - 1.5 * usq)
    feq[s][8] = weight[8] * dens * (1. + 3. * ( vx - vy) + 4.5 * ( vx - vy) * ( vx - vy) - 1.5 * usq)
  

  
def initialisation(f1, f2):
    # Definir viscosidade
    tau[0] = tauA
    if nfluids == 2:
        tau[1] = tauB

    # Definir força de interação
    g[0, 0] = gA
    if nfluids == 2:
        g[1, 1] = gB
        g[0, 1] = gAB
        g[1, 0] = gAB

    # Inicialização para 1 fluido
    if nfluids == 1:
        x_grid, y_grid = np.meshgrid(np.arange(nx), np.arange(ny), indexing="ij")
        distances = (y_grid - ny / 2.0) ** 2 + (x_grid - nx / 2.0) ** 2
        rho[0] = np.where(distances <= radius ** 2, rhol, rhog)

    # Inicialização para 2 fluidos
    elif nfluids == 2:
        mid_y = ny // 2
        mid_x = nx // 2  # Determinando o ponto central na direção x
        
        # Inicializando os fluidos A e B em cada lado da bolha
        for y in range(ny):
            for x in range(nx):
                # Distância de cada ponto ao centro
                dist_to_center = np.sqrt((x - mid_x) ** 2 + (y - mid_y) ** 2)

                # Se dentro do raio da bolha, alocar os fluidos A e B
                if dist_to_center <= radius:
                    if x < mid_x:  # Lado esquerdo
                        rho[0, x, y] = rhol  # Fluido A (líquido)
                        rho[1, x, y] = 0     # Fluido B (não tem)
                    else:  # Lado direito
                        rho[0, x, y] = 0     # Fluido A (não tem)
                        rho[1, x, y] = rhol  # Fluido B (líquido)
                else:
                    rho[0, x, y] = rhog  # Fora da bolha, atribui gás
                    rho[1, x, y] = 0     # Fora da bolha


    # Configurar o campo de velocidade inicial (velocidade zero em todos os lugares)
    ux.fill(0.0)
    uy.fill(0.0)

    # Calcular as distribuições de equilíbrio e inicializar as populações
    for s in range(nfluids):
        for y in range(ny):
            for x in range(nx):
                equilibrium(s, x, y)
                f1[s, x, y, :] = feq[s, :]
                f2[s, x, y, :] = feq[s, :]    
    
def push(f1, f2):
    for s in range(nfluids):
        omega = 1.0 / tau[s]

        for x in range(nx):  
            for y in range(ny):  
                for i in range(npop):
                    forcing[s,i] = weight[i] * (1.0 - 0.5 * omega) * ((3.0 * (cx[i] - ux[x, y]) + 9.0 * cx[i] * (cx[i] * ux[x, y] + cy[i] * uy[x, y])) * Fx[s, x, y] +
                    (3.0 * (cy[i] - uy[x, y]) + 9.0 * cy[i] * (cx[i] * ux[x, y] + cy[i] * uy[x, y])) * Fy[s, x, y])

                # Compute equilibrium distributions
                equilibrium(s, x, y)

                # Collide and propagate
                for i in range(npop):
                    x2 = (x + cx[i] + nx) % nx  # Periodic boundary in x
                    y2 = (y + cy[i] + ny) % ny  # Periodic boundary in y
                    f2[s, x2, y2, i] = f1[s, x, y, i] * (1.0 - omega) + feq[s, i] * omega + forcing[s,i]

    return

                 
def write_file(name, data, n):
    #Função auxiliar para salvar dados em disco.
    name = os.path.expanduser(os.path.join("~", "Documents", "PraticaLBM", "2 Fluidos", name))
    # Verifique se o diretório existe, caso contrário, crie-o
    os.makedirs(os.path.dirname(name), exist_ok=True)
    with open(name, "w") as fout:
        for y in range(ny):
            for x in range(nx):
                fout.write(f"{data[y * nx + x]} ")
            fout.write("\n")
        fout.write("\n")


def write_profiles(step):
    """
    Função para salvar os perfis (densidade, pressão, velocidades) no disco.
    """
    # Converter o número do passo em string com zero-padding
    step_str = str(step).zfill(5)

    # Salvar os perfis de pressão e velocidades
    press_filename = f"press_{step_str}.dat"
    velx_filename = f"velx_{step_str}.dat"
    vely_filename = f"vely_{step_str}.dat"

    write_file(press_filename, press, nx * ny)
    write_file(velx_filename, ux, nx * ny)
    write_file(vely_filename, uy, nx * ny)

    # Salvar os perfis de densidade para cada componente de fluido
    for s in range(nfluids):
        density_filename = f"density_comp{s}_{step_str}.dat"
        write_file(density_filename, rho[s], nx * ny)


def calculate_delta_pressure():
    """
    Calcula a pressão de Laplace e imprime densidades, diferenças de pressão, 
    raio da gota e tensão superficial.
    """
    rho_gas = 0.0
    rho_liq = 0.0
    press_gas = 0.0
    press_liq = 0.0

    # Pressão média do gás em um quadrado de 4 nós de malha
    for x in range(4):
        for y in range(4):
            rho_gas += rho[0,x,y]
            press_gas += press[x,y]

    # Pressão média do líquido em um quadrado de 4 nós de malha no centro
    for x in range(nx // 2 - 2, nx // 2 + 2):
        for y in range(ny // 2 - 2, ny // 2 + 2):
            rho_liq += rho[0,x,y]
            press_liq += press[x,y]

    # Calcula médias
    rho_gas /= 16.0
    rho_liq /= 16.0
    press_gas /= 16.0
    press_liq /= 16.0

    # Diferença de pressão e densidade média
    delta_press = press_liq - press_gas
    rho_av = 0.5 * (rho_gas + rho_liq)
    y = ny // 2
    rad = None

    # Determina o raio da gota
    for x in range(nx // 2):
        if rho[0,x,y] > rho_av:
            drho = rho[0,x,y] - rho[0,x-1,y]
            dx = (rho_av - rho[0,x-1,y]) / drho
            rad = (nx / 2.0 - x) + (1.0 - dx)
            break

    # Calcula a tensão superficial
    gamma = delta_press * rad

    # Imprime os resultados
    print(f"  Densities: rho_g = {rho_gas}, rho_l = {rho_liq}")
    print(f"  Pressure difference: dp = {delta_press}")
    print(f"  Droplet radius: r = {rad}")
    print(f"  Surface tension: gamma = {gamma}")

    return


# Função para imprimir status, fora do Numba
def print_status(step, elapsed_time):
    print("Running time step {}".format(step))
    print("Overall CPU time required: {:.2f} sec".format(elapsed_time))
    mlups = nx * ny * nsteps / (elapsed_time * 1e6)
    print("This corresponds to {:.2f} MLUPS".format(mlups))

# Função para criar animação, fora do Numba
def create_animation(output_dir):
    with imageio.get_writer("densidade_animacao.gif", mode="I", duration=0.1) as writer:
        frame_files = sorted(glob.glob("{}frame_*.png".format(output_dir)))  # Ordena os frames corretamente
        for filename in frame_files:
            image = imageio.imread(filename)
            writer.append_data(image)

    print("Animação salva como 'densidade_animacao.gif'")

def main():
    # Configurar cronômetro da simulação
    start = time.time()

    # Alocar memória para populações
    f1 = np.zeros((nfluids, nx, ny, npop))  # Populações antigas
    f2 = np.zeros((nfluids, nx, ny, npop))  # Populações novas
    # Inicializar domínio
    initialisation(f1, f2)

    # Loop principal
    for step in range(nsteps + 1):
        # Calcular campo de densidade
        compute_density(f1)

        # Calcular forças SC
        computeSCForces()

        # Calcular velocidade baricêntrica
        computeVelocity(f1)

        # Colidir e propagar
        push(f1, f2)

        # Trocar populações antigas e novas
        f1, f2 = f2, f1

        # Escrever dados em disco/console
        if step % noutput == 0:
            print_status(step, time.time() - start)
            computePressure()
            #write_profiles(step)
            calculate_delta_pressure()
            rho_summed = np.einsum('sxy->xy', rho)
            rho_matriz = rho_summed.reshape(nx, ny)
            plt.figure(figsize=(6, 6))
            plt.imshow(rho_matriz, cmap="viridis", origin="lower")
            plt.colorbar(label="Densidade")
            plt.title("Frame {}".format(step))
            plt.savefig("{}frame_{:03d}.png".format(output_dir, int(step / 10)))
            plt.close()

    # Exibir estatísticas de desempenho
    finish = time.time()
    elapsed_time = finish - start
    print_status(nsteps, elapsed_time)  # Imprimir estatísticas no final

# Chamar a função principal
if __name__ == "__main__":
    main()
# Out:
# Running time step 0
# Overall CPU time required: 0.68 sec
# This corresponds to 12.06 MLUPS
#   Densities: rho_g = 0.14999999999999997, rho_l = 1.05
#   Pressure difference: dp = 0.0
#   Droplet radius: r = 15.76923076923077
#   Surface tension: gamma = 0.0
# /tmp/ipykernel_4273/781145626.py:102: RuntimeWarning: overflow encountered in exp
#   psinb[x,y] = rho0 * (1 - np.exp(-rho[s,x2var,y2var] / rho0))  # Psi do vizinho
# /tmp/ipykernel_4273/781145626.py:106: RuntimeWarning: invalid value encountered in scalar subtract
#   Fx[s, x, y] -= g[s, ss] * psiloc * fxtemp
# /tmp/ipykernel_4273/781145626.py:107: RuntimeWarning: invalid value encountered in scalar subtract
#   Fy[s, x, y] -= g[s, ss] * psiloc * fytemp
# /tmp/ipykernel_4273/781145626.py:104: RuntimeWarning: invalid value encountered in scalar multiply
#   fytemp += weight[i] * cy[i] * psinb[x,y]
# /tmp/ipykernel_4273/781145626.py:103: RuntimeWarning: invalid value encountered in scalar multiply
#   fxtemp += weight[i] * cx[i] * psinb[x,y]
# /tmp/ipykernel_4273/781145626.py:105: RuntimeWarning: overflow encountered in exp
#   psiloc = rho0 * (1 - np.exp(-rho[s,x,y] / rho0)) # Psi local
# /tmp/ipykernel_4273/781145626.py:104: RuntimeWarning: invalid value encountered in scalar add
#   fytemp += weight[i] * cy[i] * psinb[x,y]
# /tmp/ipykernel_4273/781145626.py:103: RuntimeWarning: invalid value encountered in scalar add
#   fxtemp += weight[i] * cx[i] * psinb[x,y]
# /tmp/ipykernel_4273/781145626.py:106: RuntimeWarning: invalid value encountered in scalar multiply
#   Fx[s, x, y] -= g[s, ss] * psiloc * fxtemp
# /tmp/ipykernel_4273/781145626.py:107: RuntimeWarning: invalid value encountered in scalar multiply
#   Fy[s, x, y] -= g[s, ss] * psiloc * fytemp
# Running time step 100
# Overall CPU time required: 59.75 sec
# This corresponds to 0.14 MLUPS
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 401
#     399 # Chamar a função principal
#     400 if __name__ == "__main__":
# --> 401     main()
#
# Cell In[3], line 384, in main()
#     382 computePressure()
#     383 #write_profiles(step)
# --> 384 calculate_delta_pressure()
#     385 rho_summed = np.einsum('sxy->xy', rho)
#     386 rho_matriz = rho_summed.reshape(nx, ny)
#
# Cell In[3], line 324, in calculate_delta_pressure()
#     321         break
#     323 # Calcula a tensão superficial
# --> 324 gamma = delta_press * rad
#     326 # Imprime os resultados
#     327 print(f"  Densities: rho_g = {rho_gas}, rho_l = {rho_liq}")
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'
